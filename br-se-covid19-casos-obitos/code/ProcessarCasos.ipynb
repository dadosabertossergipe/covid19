# %% [markdown]
# # Dados de Casos e Óbitos
#
# Os dados de casos e óbitos são filtrados a partir dos dados disponibilizados pelo site (brasil.io)[https://brasil.io]. Os dados mais atualizados são apenas do estado como um todos. Os dados dos municípios não estão atualizados.
#
# O arquivo de `input` não está incluso nesse repositório por conta do tamanho.

# %%
import pandas as pd

# %%
dados_vacinacao = pd.read_csv("../input/brasilio/caso_full.csv")

# %%
dados_sergipe = dados_vacinacao.query("state == 'SE' and place_type == 'state'").sort_values(by='date')
dados_sergipe = dados_sergipe[['date','epidemiological_week','last_available_confirmed','last_available_deaths','new_confirmed','new_deaths']]
dados_sergipe = dados_sergipe.reset_index(drop=True)
dados_sergipe['mean7_confirmed'] = dados_sergipe['new_confirmed'].rolling(window=7).mean()
dados_sergipe['mean7_deaths'] = dados_sergipe['new_deaths'].rolling(window=7).mean()
dados_sergipe
# Out:
#            date  epidemiological_week  last_available_confirmed  \
# 0    2020-03-14                202011                         1
# 1    2020-03-15                202012                         1
# 2    2020-03-16                202012                         5
# 3    2020-03-17                202012                         5
# 4    2020-03-18                202012                         6
# ..          ...                   ...                       ...
# 688  2022-01-31                202205                    293716
# 689  2022-02-01                202205                    295696
# 690  2022-02-02                202205                    297332
# 691  2022-02-03                202205                    299127
# 692  2022-02-04                202205                    301161
#
#      last_available_deaths  new_confirmed  new_deaths  mean7_confirmed  \
# 0                        0              1           0              NaN
# 1                        0              0           0              NaN
# 2                        0              4           0              NaN
# 3                        0              0           0              NaN
# 4                        0              1           0              NaN
# ..                     ...            ...         ...              ...
# 688                   6098           1549           5      1340.428571
# 689                   6103           1980           5      1538.285714
# 690                   6109           1636           6      1592.142857
# 691                   6115           1795           6      1702.142857
# 692                   6120           2034           5      1726.428571
#
#      mean7_deaths
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 688      3.285714
# 689      3.714286
# 690      4.285714
# 691      4.857143
# 692      5.142857
#
# [693 rows x 8 columns]

# %%
dados_sergipe.columns = ['data','semana_epidemiologica','total_casos_confirmados','total_obitos_confirmados','diario_casos_confirmados','diario_obitos_confirmados','media_movel7_casos','media_movel7_obitos']
dados_sergipe
# Out:
#            data  semana_epidemiologica  total_casos_confirmados  \
# 0    2020-03-14                 202011                        1
# 1    2020-03-15                 202012                        1
# 2    2020-03-16                 202012                        5
# 3    2020-03-17                 202012                        5
# 4    2020-03-18                 202012                        6
# ..          ...                    ...                      ...
# 688  2022-01-31                 202205                   293716
# 689  2022-02-01                 202205                   295696
# 690  2022-02-02                 202205                   297332
# 691  2022-02-03                 202205                   299127
# 692  2022-02-04                 202205                   301161
#
#      total_obitos_confirmados  diario_casos_confirmados  \
# 0                           0                         1
# 1                           0                         0
# 2                           0                         4
# 3                           0                         0
# 4                           0                         1
# ..                        ...                       ...
# 688                      6098                      1549
# 689                      6103                      1980
# 690                      6109                      1636
# 691                      6115                      1795
# 692                      6120                      2034
#
#      diario_obitos_confirmados  media_movel7_casos  media_movel7_obitos
# 0                            0                 NaN                  NaN
# 1                            0                 NaN                  NaN
# 2                            0                 NaN                  NaN
# 3                            0                 NaN                  NaN
# 4                            0                 NaN                  NaN
# ..                         ...                 ...                  ...
# 688                          5         1340.428571             3.285714
# 689                          5         1538.285714             3.714286
# 690                          6         1592.142857             4.285714
# 691                          6         1702.142857             4.857143
# 692                          5         1726.428571             5.142857
#
# [693 rows x 8 columns]

# %%
dados_sergipe.to_csv("../output/se_covid19_casos_obitos.csv", index=False)
